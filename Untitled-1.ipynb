# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
import plotly.express as px
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from sklearn import neighbors
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
my_scaler =  StandardScaler()
pd.set_option('display.max_columns',34)

df = pd.read_csv('data.csv')
df.pop('Unnamed: 0')
df = df.rename(columns = {'Type of ownership' : 'Type of Ownership',
                      'min_salary' : 'Min. Salary',
                      'max_salary' : 'Max. Salary',
                      'avg_salary' : 'Avg. Salary',
                      'job_state' : 'Job State',
                      'same_state' : 'Same State',
                      'age' : 'Age',
                      'python_yn' : 'Python Exp.',
                      'R_yn' : 'R Exp.',
                      'spark' : 'Spark Exp.',
                      'aws' : 'AWS Exp.',
                      'excel' : 'Excel Exp.',
                      'job_simp' : 'Title Simplified',
                     'Headquarters' : 'HQ',
                     'hourly' : 'Hourly',
                     'desc_len' : 'Description Length',
                     'num_comp' : '# of Competitors',
                     'employer_provided' : 'Employer Provided',
                     'seniority' : 'Seniority',
                     })
df.pop('R Exp.')
df['Title Simplified'] = df['Title Simplified'].str.title()
df['Title Simplified'] = df['Title Simplified'].str.replace('Mle', 'MLE')
df['Min. Salary'] = df['Min. Salary']*1000
df['Max. Salary'] = df['Max. Salary']*1000
df['Avg. Salary'] = df['Avg. Salary']*1000

df1 = df

#removing data
#df = df.drop(['Competitors', '# of Competitors'], axis=1)
df = df.loc[(df['Age'] >= 18) & (df['Age'] <= 120)]
#df_notxt = df.drop(['Job Description'], axis=1)
df['Title Simplified'] = df['Title Simplified'].replace('Na', 'Na')
#df = df[df['Title Simplified'].apply(lambda x: str(x).lower() != 'nan')]
df['Revenue'] = df['Revenue'].replace('Unknown', 'Na')
#df = df[df['Revenue'].apply(lambda x: str(x).lower() != 'nan')]
df['Type of Ownership'] = df['Type of Ownership'].replace('Unknown', 'Na')
#df = df[df['Type of Ownership'].apply(lambda x: str(x).lower() != 'nan')]
df.reset_index(drop=True, inplace=True)
# Out:
# /var/folders/xy/61k0hv8s0lxckrn761984n740000gn/T/ipykernel_28407/1739242367.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Title Simplified'] = df['Title Simplified'].replace('Na', 'Na')
# /var/folders/xy/61k0hv8s0lxckrn761984n740000gn/T/ipykernel_28407/1739242367.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Revenue'] = df['Revenue'].replace('Unknown', 'Na')
# /var/folders/xy/61k0hv8s0lxckrn761984n740000gn/T/ipykernel_28407/1739242367.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Type of Ownership'] = df['Type of Ownership'].replace('Unknown', 'Na')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
import plotly.express as px
import plotly.graph_objects as go
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv('data.csv')

df = pd.read_csv('data.csv')
df.pop('Unnamed: 0')
#df['age'] = [2023 - i  if i != -1 else i for i in df['Founded']]
df = df.rename(columns = {'Type of ownership' : 'Type of Ownership',
                      'min_salary' : 'Min. Salary',
                      'max_salary' : 'Max. Salary',
                      'avg_salary' : 'Avg. Salary',
                      'job_state' : 'Job State',
                      'same_state' : 'Same State',
                      'age' : 'Age',
                      'python_yn' : 'Python Exp.',
                      'R_yn' : 'R Exp.',
                      'spark' : 'Spark Exp.',
                      'aws' : 'AWS Exp.',
                      'excel' : 'Excel Exp.',
                      'job_simp' : 'Title Simplified',
                     'Headquarters' : 'HQ',
                     'hourly' : 'Hourly',
                     'desc_len' : 'Description Length',
                     'num_comp' : '# of Competitors',
                     'employer_provided' : 'Employer Provided',
                     'seniority' : 'Seniority',
                     })
df.pop('R Exp.')
df['Title Simplified'] = df['Title Simplified'].str.title()
df['Title Simplified'] = df['Title Simplified'].str.replace('Mle', 'MLE')
df['Min. Salary'] = df['Min. Salary']*1000
df['Max. Salary'] = df['Max. Salary']*1000
df['Avg. Salary'] = df['Avg. Salary']*1000
df.replace({"Na": np.nan, "NaN": np.nan, "-1": np.nan, "Unknown / Non-Applicable": np.nan}, inplace=True)
df = df.drop(['Competitors', '# of Competitors'], axis=1)
df_orig = df

#removing data

df = df.loc[(df['Age'] >= 18) & (df['Age'] <= 120)]
#df_notxt = df.drop(['Job Description'], axis=1)
#mask = df.isin([-1]).any(axis=1)
#df = df[~mask]
#df = df[df['Title Simplified'].apply(lambda x: str(x).lower() != 'nan')]

#df = df[df['Revenue'].apply(lambda x: str(x).lower() != 'nan')]

df['Type of Ownership'] = df['Type of Ownership'].replace('Unknown', 'Na')
#df = df[df['Type of Ownership'].apply(lambda x: str(x).lower() != 'nan')]
df.reset_index(drop=True, inplace=True)


df_new = df.drop(['Salary Estimate', 'Job Description', 'Company Name', 'Size', 'Revenue',
       'Hourly', 'Employer Provided', 'company_txt', 'Seniority', 'Description Length'], axis=1)
df_stats = df_new.drop(['Python Exp.', 'AWS Exp.', 'Spark Exp.', 'Excel Exp.', 'Same State','Job Title', 'Location', 'HQ', 'Type of Ownership', 'Industry','Sector', 'Title Simplified' ], axis=1)

df = df[df['Avg. Salary'] > 30000]
#for col in df.columns:
#    unique_col[col] = df[col].unique()

scaler = MinMaxScaler()
sd_scaler = StandardScaler()
state_counts = df['Job State'].value_counts().reset_index()
state_counts.columns = ['Job State', 'Count']
state_counts['Normalized Count'] = scaler.fit_transform(state_counts[['Count']])
state_counts['Standardized Count'] = sd_scaler.fit_transform(state_counts[['Count']])

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $56K-$97K (Glassdoor est.)
# 3             Data Scientist  $86K-$143K (Glassdoor est.)
# 4             Data Scientist  $71K-$119K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 3  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 4  CyrusOne is seeking a talented Data Scientist ...     3.4
#
#                                  Company Name         Location             HQ  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM     Goleta, CA
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  Baltimore, MD
# 2                                   PNNL\n3.8     Richland, WA   Richland, WA
# 3                     Affinity Solutions\n2.9     New York, NY   New York, NY
# 4                               CyrusOne\n3.4       Dallas, TX     Dallas, TX
#
#                      Size  Founded   Type of Ownership  \
# 0   501 to 1000 employees     1973   Company - Private
# 1        10000+ employees     1984  Other Organization
# 2  1001 to 5000 employees     1965          Government
# 3     51 to 200 employees     1998   Company - Private
# 4    201 to 500 employees     2000    Company - Public
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                            Energy  Oil, Gas, Energy & Utilities
# 3           Advertising & Marketing             Business Services
# 4                       Real Estate                   Real Estate
#
#                             Revenue  Hourly  Employer Provided  Min. Salary  \
# 0         $50 to $100 million (USD)       0                  0        53000
# 1            $2 to $5 billion (USD)       0                  0        63000
# 2  $500 million to $1 billion (USD)       0                  0        56000
# 3          Unknown / Non-Applicable       0                  0        86000
# 4            $1 to $2 billion (USD)       0                  0        71000
#
#    Max. Salary  Avg. Salary                            company_txt Job State  \
# 0        91000      72000.0                      Tecolote Research        NM
# 1       112000      87500.0  University of Maryland Medical System        MD
# 2        97000      76500.0                                   PNNL        WA
# 3       143000     114500.0                     Affinity Solutions        NY
# 4       119000      95000.0                               CyrusOne        TX
#
#    Same State  Age  Python Exp.  Spark Exp.  AWS Exp.  Excel Exp.  \
# 0           0   47            1           0         0           1
# 1           0   36            1           0         0           0
# 2           1   55            1           0         0           0
# 3           1   22            1           0         0           1
# 4           1   20            1           0         1           1
#
#   Title Simplified Seniority  Description Length
# 0   Data Scientist        na                2536
# 1   Data Scientist        na                4783
# 2   Data Scientist        na                3883
# 3   Data Scientist        na                2728
# 4   Data Scientist        na                3747

# %% [markdown]
# predective testing
# - read the job description and can see whether or not the job (is a given sector/industry)
# - a tighter range for the salary than what was given
# - test/train data, given certrain X values, to determine the sector/industry/revenue
# - is it possible to predict how many competitors there will be for a particular position
#
#
#
# being able to predict the revenue of a given company for you to determine whether you apply to the job or not based on year founded

# %%
df_orig.shape
# Out:
# (742, 31)

# %%
#reviewing missing Revenues and Job Titles
df_orig[df_orig['Revenue'] == 'Unknown / Non-Applicable']
# Out:
#                                              Job Title  \
# 4                                       Data Scientist
# 6                                       Data Scientist
# 13                                        Data Analyst
# 15                                     Data Engineer I
# 17                             Customer Data Scientist
# ..                                                 ...
# 729               Associate Scientist, LC/MS Biologics
# 730    Research Scientist, Immunology - Cancer Biology
# 732                    Machine Learning Engineer (NLP)
# 733                                Senior Data Analyst
# 739  Project Scientist - Auton Lab, Robotics Institute
#
#                           Salary Estimate  \
# 4             $86K-$143K (Glassdoor est.)
# 6              $54K-$93K (Glassdoor est.)
# 13             $46K-$85K (Glassdoor est.)
# 15           $102K-$190K (Glassdoor est.)
# 17           $118K-$189K (Glassdoor est.)
# ..                                    ...
# 729            $44K-$96K (Glassdoor est.)
# 730  Employer Provided Salary:$100K-$140K
# 732           $80K-$142K (Glassdoor est.)
# 733           $99K-$178K (Glassdoor est.)
# 739            $56K-$91K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# 6    Job Description\n\n**Please only local candida...     4.1
# 13   Are you an experienced Data Analyst, skilled a...     4.1
# 15   This opportunity is within Audibles Data Engin...     3.6
# 17   Company Overview\n\nH2O.ai is the open source ...     4.3
# ..                                                 ...     ...
# 729  Q2 Solutions is a leading clinical trial labor...     2.9
# 730  Research Scientist, Immunology - Cancer Biolog...    -1.0
# 732  CK-12’s mission is to provide free access to o...     4.1
# 733  Senior Data Analyst\n\nAbout us\n\n\nLife360 b...     3.9
# 739  The Auton Lab at Carnegie Mellon University is...     2.6
#
#                             Company Name           Location  \
# 4                Affinity Solutions\n2.9       New York, NY
# 6                ClearOne Advantage\n4.1      Baltimore, MD
# 13                           Yesler\n4.1        Seattle, WA
# 15                          Audible\n3.6         Newark, NJ
# 17                           h2o.ai\n4.3  Mountain View, CA
# ..                                   ...                ...
# 729                    Q2 Solutions\n2.9         Ithaca, NY
# 730                           Kronos Bio      Cambridge, MA
# 732                CK-12 Foundation\n4.1      Palo Alto, CA
# 733                         Life360\n3.9  San Francisco, CA
# 739  Software Engineering Institute\n2.6     Pittsburgh, PA
#
#                     HQ                    Size  Founded  \
# 4         New York, NY     51 to 200 employees     1998
# 6        Baltimore, MD   501 to 1000 employees     2008
# 13         Seattle, WA    201 to 500 employees     2012
# 15          Newark, NJ  1001 to 5000 employees     1995
# 17   Mountain View, CA    201 to 500 employees     2011
# ..                 ...                     ...      ...
# 729    Morrisville, NC  1001 to 5000 employees     2015
# 730      San Mateo, CA                 Unknown       -1
# 732      Palo Alto, CA       1 to 50 employees     2007
# 733  San Francisco, CA     51 to 200 employees     2008
# 739     Pittsburgh, PA   501 to 1000 employees     1984
#
#                   Type of Ownership                                  Industry  \
# 4                 Company - Private                   Advertising & Marketing
# 6                 Company - Private                     Banks & Credit Unions
# 13                Company - Private                   Advertising & Marketing
# 15   Subsidiary or Business Segment  Motion Picture Production & Distribution
# 17                Company - Private   Enterprise Software & Network Solutions
# ..                              ...                                       ...
# 729               Company - Private                 Biotech & Pharmaceuticals
# 730               Company - Private                                        -1
# 732               Company - Private                            K-12 Education
# 733                Company - Public              Computer Hardware & Software
# 739            College / University                   Colleges & Universities
#
#                         Sector                   Revenue  \
# 4            Business Services  Unknown / Non-Applicable
# 6                      Finance  Unknown / Non-Applicable
# 13           Business Services  Unknown / Non-Applicable
# 15                       Media  Unknown / Non-Applicable
# 17      Information Technology  Unknown / Non-Applicable
# ..                         ...                       ...
# 729  Biotech & Pharmaceuticals  Unknown / Non-Applicable
# 730                         -1  Unknown / Non-Applicable
# 732                  Education  Unknown / Non-Applicable
# 733     Information Technology  Unknown / Non-Applicable
# 739                  Education  Unknown / Non-Applicable
#
#                               Competitors  Hourly  Employer Provided  \
# 4    Commerce Signals, Cardlytics, Yodlee       0                  0
# 6                                      -1       0                  0
# 13                                     -1       0                  0
# 15                                     -1       0                  0
# 17                                     -1       0                  0
# ..                                    ...     ...                ...
# 729                                    -1       0                  0
# 730                                    -1       0                  1
# 732                                    -1       0                  0
# 733                                    -1       0                  0
# 739                                    -1       0                  0
#
#      Min. Salary  Max. Salary  Avg. Salary                     company_txt  \
# 4          86000       143000     114500.0              Affinity Solutions
# 6          54000        93000      73500.0              ClearOne Advantage
# 13         46000        85000      65500.0                          Yesler
# 15        102000       190000     146000.0                         Audible
# 17        118000       189000     153500.0                          h2o.ai
# ..           ...          ...          ...                             ...
# 729        44000        96000      70000.0                    Q2 Solutions
# 730       100000       140000     120000.0                      Kronos Bio
# 732        80000       142000     111000.0                CK-12 Foundation
# 733        99000       178000     138500.0                         Life360
# 739        56000        91000      73500.0  Software Engineering Institute
#
#     Job State  Same State  Age  Python Exp.  Spark Exp.  AWS Exp.  Excel Exp.  \
# 4          NY           1   22            1           0         0           1
# 6          MD           1   12            0           0         0           1
# 13         WA           1    8            1           1         1           1
# 15         NJ           1   25            0           0         0           1
# 17         CA           1    9            1           1         1           1
# ..        ...         ...  ...          ...         ...       ...         ...
# 729        NY           0    5            0           0         0           1
# 730        MA           0   -1            0           0         0           1
# 732        CA           1   13            1           0         1           1
# 733        CA           1   12            1           0         0           0
# 739        PA           1   36            0           0         0           1
#
#     Title Simplified Seniority  Description Length  # of Competitors
# 4     Data Scientist        na                2728                 3
# 6     Data Scientist        na                1786                 0
# 13           Analyst        na                4897                 0
# 15     Data Engineer        na                1889                 0
# 17    Data Scientist        na                4163                 0
# ..               ...       ...                 ...               ...
# 729               Na        na                4707                 0
# 730               Na        na                3309                 0
# 732              MLE        na                3478                 0
# 733          Analyst    senior                5717                 0
# 739               Na        na                3078                 0
#
# [203 rows x 31 columns]

# %%
df_age = df.loc[(df['Age'] >= 18) & (df['Age'] <= 85)]
df_age.shape
# Out:
# (312, 29)

# %%
df.isna().any()
# Out:
# Job Title             False
# Salary Estimate       False
# Job Description       False
# Rating                False
# Company Name          False
# Location              False
# HQ                    False
# Size                  False
# Founded               False
# Type of Ownership     False
# Industry              False
# Sector                False
# Revenue                True
# Hourly                False
# Employer Provided     False
# Min. Salary           False
# Max. Salary           False
# Avg. Salary           False
# company_txt           False
# Job State             False
# Same State            False
# Age                   False
# Python Exp.           False
# Spark Exp.            False
# AWS Exp.              False
# Excel Exp.            False
# Title Simplified       True
# Seniority             False
# Description Length    False
# dtype: bool

# %%
df.shape
# Out:
# (349, 29)

# %%
df.isna().sum()
# Out:
# Job Title              0
# Salary Estimate        0
# Job Description        0
# Rating                 0
# Company Name           0
# Location               0
# HQ                     0
# Size                   0
# Founded                0
# Type of Ownership      0
# Industry               0
# Sector                 0
# Revenue               63
# Hourly                 0
# Employer Provided      0
# Min. Salary            0
# Max. Salary            0
# Avg. Salary            0
# company_txt            0
# Job State              0
# Same State             0
# Age                    0
# Python Exp.            0
# Spark Exp.             0
# AWS Exp.               0
# Excel Exp.             0
# Title Simplified      76
# Seniority              0
# Description Length     0
# dtype: int64

# %%
df_orig.isna().sum()
# Out:
# Job Title               0
# Salary Estimate         0
# Job Description         0
# Rating                  0
# Company Name            0
# Location                0
# HQ                      1
# Size                    1
# Founded                 0
# Type of Ownership       1
# Industry               10
# Sector                 10
# Revenue               204
# Competitors           460
# Hourly                  0
# Employer Provided       0
# Min. Salary             0
# Max. Salary             0
# Avg. Salary             0
# company_txt             0
# Job State               0
# Same State              0
# Age                     0
# Python Exp.             0
# Spark Exp.              0
# AWS Exp.                0
# Excel Exp.              0
# Title Simplified      184
# Seniority               0
# Description Length      0
# # of Competitors        0
# dtype: int64

# %%
missing_vals = df_orig.isna().sum()
fig = px.histogram(x=missing_vals.index, y=missing_vals.values,  color_discrete_sequence=['#330C73'], labels={"x": "Column", "y": "Missing Values Count"}, title="Histogram of Missing Values in Each Column")
fig.show()

# %%
df['Sector'].unique()
# Out:
# array(['Aerospace & Defense', 'Health Care',
#        'Oil, Gas, Energy & Utilities', 'Business Services', 'Real Estate',
#        'Retail', 'Media', 'Insurance', 'Transportation & Logistics',
#        'Finance', 'Biotech & Pharmaceuticals', 'Telecommunications',
#        'Information Technology', 'Manufacturing', 'Government',
#        'Agriculture & Forestry', 'Education',
#        'Arts, Entertainment & Recreation', 'Travel & Tourism',
#        'Non-Profit', 'Construction, Repair & Maintenance'], dtype=object)

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'HQ', 'Size', 'Founded',
#        'Type of Ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Hourly', 'Employer Provided', 'Min. Salary', 'Max. Salary',
#        'Avg. Salary', 'company_txt', 'Job State', 'Same State', 'Age',
#        'Python Exp.', 'Spark Exp.', 'AWS Exp.', 'Excel Exp.',
#        'Title Simplified', 'Seniority', 'Description Length',
#        '# of Competitors'],
#       dtype='object')

# %%
df['Revenue'].unique().tolist()
# Out:
# ['$50 to $100 million (USD)',
#  '$2 to $5 billion (USD)',
#  '$500 million to $1 billion (USD)',
#  'Unknown / Non-Applicable',
#  '$1 to $2 billion (USD)',
#  '$10+ billion (USD)',
#  '$10 to $25 million (USD)',
#  '$100 to $500 million (USD)',
#  '$5 to $10 billion (USD)',
#  '$25 to $50 million (USD)',
#  '$5 to $10 million (USD)']

# %%
df['Industry'].unique().tolist()
# Out:
# ['Aerospace & Defense',
#  'Health Care Services & Hospitals',
#  'Energy',
#  'Advertising & Marketing',
#  'Real Estate',
#  'Research & Development',
#  'Department, Clothing, & Shoe Stores',
#  'Motion Picture Production & Distribution',
#  'Insurance Carriers',
#  'Logistics & Supply Chain',
#  'Banks & Credit Unions',
#  'Biotech & Pharmaceuticals',
#  'Telecommunications Services',
#  'Computer Hardware & Software',
#  'IT Services',
#  'Enterprise Software & Network Solutions',
#  'Industrial Manufacturing',
#  'Sporting Goods Stores',
#  'Wholesale',
#  'Consulting',
#  'Financial Analytics & Research',
#  'Federal Agencies',
#  'Security Services',
#  'Transportation Equipment Manufacturing',
#  'Farm Support Services',
#  'Architectural & Engineering Services',
#  'Brokerage Services',
#  'Consumer Products Manufacturing',
#  'Colleges & Universities',
#  'Investment Banking & Asset Management',
#  'Gambling',
#  'Gas Stations',
#  'Food & Beverage Manufacturing',
#  'Travel Agencies',
#  'Video Games',
#  'Trucking',
#  'Internet',
#  'Social Assistance',
#  'Telecommunications Manufacturing',
#  'Stock Exchanges',
#  'Construction',
#  'Lending',
#  'Financial Transaction Processing',
#  'TV Broadcast & Cable Networks',
#  'Health Care Products Manufacturing',
#  'Beauty & Personal Accessories Stores']

# %%
features = list(df.columns.values)

# %%
df_array = df.to_numpy()

# %%
df_num_only = df._get_numeric_data()
df_num_only
# Out:
#      Rating  Founded  Hourly  Employer Provided  Min. Salary  Max. Salary  \
# 0       3.8     1973       0                  0        53000        91000
# 1       3.4     1984       0                  0        63000       112000
# 2       3.8     1965       0                  0        56000        97000
# 3       2.9     1998       0                  0        86000       143000
# 4       3.4     2000       0                  0        71000       119000
# ..      ...      ...     ...                ...          ...          ...
# 364     3.2     1958       0                  0        56000        99000
# 365     3.3     1976       1                  1        50000        56000
# 366     3.4     1988       0                  0        61000       119000
# 367     2.6     1984       0                  0        56000        91000
# 368     3.6     1967       0                  0        61000       126000
#
#      Avg. Salary  Same State  Age  Python Exp.  Spark Exp.  AWS Exp.  \
# 0        72000.0           0   47            1           0         0
# 1        87500.0           0   36            1           0         0
# 2        76500.0           1   55            1           0         0
# 3       114500.0           1   22            1           0         0
# 4        95000.0           1   20            1           0         1
# ..           ...         ...  ...          ...         ...       ...
# 364      77500.0           0   62            0           0         0
# 365      26500.0           1   44            0           0         0
# 366      90000.0           1   32            0           1         0
# 367      73500.0           1   36            0           0         0
# 368      93500.0           0   53            1           0         0
#
#      Excel Exp.  Description Length  # of Competitors
# 0             1                2536                 0
# 1             0                4783                 0
# 2             0                3883                 3
# 3             1                2728                 3
# 4             1                3747                 3
# ..          ...                 ...               ...
# 364           0                3243                 3
# 365           1                1848                 0
# 366           1                2752                 0
# 367           1                3078                 0
# 368           0                3673                 0
#
# [369 rows x 15 columns]

# %%
df_array = df_num_only.to_numpy()
df_array
# Out:
# array([[3.800e+00, 1.973e+03, 0.000e+00, ..., 1.000e+00, 2.536e+03,
#         0.000e+00],
#        [3.400e+00, 1.984e+03, 0.000e+00, ..., 0.000e+00, 4.783e+03,
#         0.000e+00],
#        [3.800e+00, 1.965e+03, 0.000e+00, ..., 0.000e+00, 3.883e+03,
#         3.000e+00],
#        ...,
#        [3.400e+00, 1.988e+03, 0.000e+00, ..., 1.000e+00, 2.752e+03,
#         0.000e+00],
#        [2.600e+00, 1.984e+03, 0.000e+00, ..., 1.000e+00, 3.078e+03,
#         0.000e+00],
#        [3.600e+00, 1.967e+03, 0.000e+00, ..., 0.000e+00, 3.673e+03,
#         0.000e+00]])

# %%
df_array
# Out:
# array([[3.800e+00, 1.973e+03, 0.000e+00, ..., 1.000e+00, 2.536e+03,
#         0.000e+00],
#        [3.400e+00, 1.984e+03, 0.000e+00, ..., 0.000e+00, 4.783e+03,
#         0.000e+00],
#        [3.800e+00, 1.965e+03, 0.000e+00, ..., 0.000e+00, 3.883e+03,
#         3.000e+00],
#        ...,
#        [3.400e+00, 1.988e+03, 0.000e+00, ..., 1.000e+00, 2.752e+03,
#         0.000e+00],
#        [2.600e+00, 1.984e+03, 0.000e+00, ..., 1.000e+00, 3.078e+03,
#         0.000e+00],
#        [3.600e+00, 1.967e+03, 0.000e+00, ..., 0.000e+00, 3.673e+03,
#         0.000e+00]])

# %%
type(df['Title Simplified'])
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $56K-$97K (Glassdoor est.)
# 3             Data Scientist  $86K-$143K (Glassdoor est.)
# 4             Data Scientist  $71K-$119K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 3  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 4  CyrusOne is seeking a talented Data Scientist ...     3.4
#
#                                  Company Name         Location             HQ  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM     Goleta, CA
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  Baltimore, MD
# 2                                   PNNL\n3.8     Richland, WA   Richland, WA
# 3                     Affinity Solutions\n2.9     New York, NY   New York, NY
# 4                               CyrusOne\n3.4       Dallas, TX     Dallas, TX
#
#                      Size  Founded   Type of Ownership  \
# 0   501 to 1000 employees     1973   Company - Private
# 1        10000+ employees     1984  Other Organization
# 2  1001 to 5000 employees     1965          Government
# 3     51 to 200 employees     1998   Company - Private
# 4    201 to 500 employees     2000    Company - Public
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                            Energy  Oil, Gas, Energy & Utilities
# 3           Advertising & Marketing             Business Services
# 4                       Real Estate                   Real Estate
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2  $500 million to $1 billion (USD)
# 3          Unknown / Non-Applicable
# 4            $1 to $2 billion (USD)
#
#                                          Competitors  Hourly  \
# 0                                                 -1       0
# 1                                                 -1       0
# 2  Oak Ridge National Laboratory, National Renewa...       0
# 3               Commerce Signals, Cardlytics, Yodlee       0
# 4                  Digital Realty, CoreSite, Equinix       0
#
#    Employer Provided  Min. Salary  Max. Salary  Avg. Salary  \
# 0                  0        53000        91000      72000.0
# 1                  0        63000       112000      87500.0
# 2                  0        56000        97000      76500.0
# 3                  0        86000       143000     114500.0
# 4                  0        71000       119000      95000.0
#
#                              company_txt Job State  Same State  Age  \
# 0                      Tecolote Research        NM           0   47
# 1  University of Maryland Medical System        MD           0   36
# 2                                   PNNL        WA           1   55
# 3                     Affinity Solutions        NY           1   22
# 4                               CyrusOne        TX           1   20
#
#    Python Exp.  Spark Exp.  AWS Exp.  Excel Exp. Title Simplified Seniority  \
# 0            1           0         0           1   Data Scientist        na
# 1            1           0         0           0   Data Scientist        na
# 2            1           0         0           0   Data Scientist        na
# 3            1           0         0           1   Data Scientist        na
# 4            1           0         1           1   Data Scientist        na
#
#    Description Length  # of Competitors
# 0                2536                 0
# 1                4783                 0
# 2                3883                 3
# 3                2728                 3
# 4                3747                 3

# %%
X = df_num_only.copy()

# %%
y = df['Revenue'].to_numpy()
y
# Out:
# array(['$50 to $100 million (USD)', '$2 to $5 billion (USD)',
#        '$500 million to $1 billion (USD)', 'Unknown / Non-Applicable',
#        '$1 to $2 billion (USD)', '$1 to $2 billion (USD)',
#        '$10+ billion (USD)', 'Unknown / Non-Applicable',
#        '$500 million to $1 billion (USD)', 'Unknown / Non-Applicable',
#        '$10 to $25 million (USD)', '$100 to $500 million (USD)',
#        '$500 million to $1 billion (USD)',
#        '$500 million to $1 billion (USD)', '$10+ billion (USD)',
#        '$2 to $5 billion (USD)', 'Unknown / Non-Applicable',
#        '$1 to $2 billion (USD)', '$100 to $500 million (USD)',
#        '$2 to $5 billion (USD)', '$10+ billion (USD)',
#        '$2 to $5 billion (USD)', '$100 to $500 million (USD)',
#        '$10+ billion (USD)', 'Unknown / Non-Applicable',
#        '$10+ billion (USD)', '$100 to $500 million (USD)',
#        '$10+ billion (USD)', '$1 to $2 billion (USD)',
#        '$500 million to $1 billion (USD)', '$5 to $10 billion (USD)',
#        '$100 to $500 million (USD)', 'Unknown / Non-Applicable',
#        '$10+ billion (USD)', '$50 to $100 million (USD)',
#        'Unknown / Non-Applicable', '$10 to $25 million (USD)',
#        '$500 million to $1 billion (USD)', '$25 to $50 million (USD)',
#        '$1 to $2 billion (USD)', '$50 to $100 million (USD)',
#        '$100 to $500 million (USD)', '$10+ billion (USD)',
#        '$25 to $50 million (USD)', 'Unknown / Non-Applicable',
#        '$100 to $500 million (USD)', '$1 to $2 billion (USD)',
#        '$100 to $500 million (USD)', '$10+ billion (USD)',
#        '$1 to $2 billion (USD)', '$2 to $5 billion (USD)',
#        'Unknown / Non-Applicable', 'Unknown / Non-Applicable',
#        '$100 to $500 million (USD)', '$5 to $10 billion (USD)',
#        'Unknown / Non-Applicable', '$2 to $5 billion (USD)',
#        '$50 to $100 million (USD)', 'Unknown / Non-Applicable',
#        '$25 to $50 million (USD)', 'Unknown / Non-Applicable',
#        '$1 to $2 billion (USD)', 'Unknown / Non-Applicable',
#        '$2 to $5 billion (USD)', '$100 to $500 million (USD)',
#        '$25 to $50 million (USD)', '$100 to $500 million (USD)',
#        '$10+ billion (USD)', '$100 to $500 million (USD)',
#        '$1 to $2 billion (USD)', '$500 million to $1 billion (USD)',
#        '$100 to $500 million (USD)', '$1 to $2 billion (USD)',
#        'Unknown / Non-Applicable', '$500 million to $1 billion (USD)',
#        '$2 to $5 billion (USD)', '$100 to $500 million (USD)',
#        '$5 to $10 billion (USD)', '$500 million to $1 billion (USD)',
#        '$10+ billion (USD)', '$2 to $5 billion (USD)',
#        '$500 million to $1 billion (USD)', '$10+ billion (USD)',
#        '$25 to $50 million (USD)', '$50 to $100 million (USD)',
#        '$2 to $5 billion (USD)', 'Unknown / Non-Applicable',
#        '$10 to $25 million (USD)', '$100 to $500 million (USD)',
#        '$1 to $2 billion (USD)', '$1 to $2 billion (USD)',
#        'Unknown / Non-Applicable', '$25 to $50 million (USD)',
#        '$5 to $10 million (USD)', '$100 to $500 million (USD)',
#        '$50 to $100 million (USD)', 'Unknown / Non-Applicable',
#        '$500 million to $1 billion (USD)', '$10+ billion (USD)',
#        '$100 to $500 million (USD)', 'Unknown / Non-Applicable',
#        '$25 to $50 million (USD)', 'Unknown / Non-Applicable',
#        '$10+ billion (USD)', '$1 to $2 billion (USD)',
#        '$2 to $5 billion (USD)', 'Unknown / Non-Applicable',
#        'Unknown / Non-Applicable', '$10 to $25 million (USD)',
#        '$10+ billion (USD)', '$1 to $2 billion (USD)',
#        'Unknown / Non-Applicable', '$10+ billion (USD)',
#        '$2 to $5 billion (USD)', '$50 to $100 million (USD)',
#        '$10+ billion (USD)', '$500 million to $1 billion (USD)',
#        'Unknown / Non-Applicable', '$10 to $25 million (USD)',
#        '$50 to $100 million (USD)', '$100 to $500 million (USD)',
#        '$25 to $50 million (USD)', '$1 to $2 billion (USD)',
#        'Unknown / Non-Applicable', '$100 to $500 million (USD)',
#        '$50 to $100 million (USD)', '$10+ billion (USD)',
#        'Unknown / Non-Applicable', 'Unknown / Non-Applicable',
#        '$2 to $5 billion (USD)', 'Unknown / Non-Applicable',
#        '$10 to $25 million (USD)', '$10 to $25 million (USD)',
#        '$1 to $2 billion (USD)', '$100 to $500 million (USD)',
#        '$1 to $2 billion (USD)', 'Unknown / Non-Applicable',
#        '$5 to $10 billion (USD)', '$1 to $2 billion (USD)',
#        'Unknown / Non-Applicable', '$100 to $500 million (USD)',
#        '$500 million to $1 billion (USD)', '$25 to $50 million (USD)',
#        '$10 to $25 million (USD)', '$50 to $100 million (USD)',
#        '$25 to $50 million (USD)', '$10+ billion (USD)',
#        '$10+ billion (USD)', '$1 to $2 billion (USD)',
#        '$10+ billion (USD)', '$2 to $5 billion (USD)',
#        '$500 million to $1 billion (USD)', '$10+ billion (USD)',
#        '$2 to $5 billion (USD)', '$50 to $100 million (USD)',
#        '$1 to $2 billion (USD)', '$500 million to $1 billion (USD)',
#        '$1 to $2 billion (USD)', '$50 to $100 million (USD)',
#        '$5 to $10 million (USD)', 'Unknown / Non-Applicable',
#        'Unknown / Non-Applicable', '$100 to $500 million (USD)',
#        '$1 to $2 billion (USD)', 'Unknown / Non-Applicable',
#        '$5 to $10 billion (USD)', '$10+ billion (USD)',
#        '$100 to $500 million (USD)', '$50 to $100 million (USD)',
#        '$500 million to $1 billion (USD)', 'Unknown / Non-Applicable',
#        '$100 to $500 million (USD)', '$500 million to $1 billion (USD)',
#        '$10+ billion (USD)', '$10+ billion (USD)',
#        '$500 million to $1 billion (USD)', 'Unknown / Non-Applicable',
#        '$1 to $2 billion (USD)', '$25 to $50 million (USD)',
#        '$10+ billion (USD)', '$25 to $50 million (USD)',
#        '$100 to $500 million (USD)', '$500 million to $1 billion (USD)',
#        '$25 to $50 million (USD)', '$1 to $2 billion (USD)',
#        '$1 to $2 billion (USD)', 'Unknown / Non-Applicable',
#        '$100 to $500 million (USD)', 'Unknown / Non-Applicable',
#        'Unknown / Non-Applicable', '$2 to $5 billion (USD)',
#        '$1 to $2 billion (USD)', '$10+ billion (USD)',
#        '$10 to $25 million (USD)', 'Unknown / Non-Applicable',
#        '$100 to $500 million (USD)', 'Unknown / Non-Applicable',
#        '$100 to $500 million (USD)', '$25 to $50 million (USD)',
#        '$1 to $2 billion (USD)', '$5 to $10 billion (USD)',
#        '$10+ billion (USD)', '$2 to $5 billion (USD)',
#        '$500 million to $1 billion (USD)', '$100 to $500 million (USD)',
#        '$5 to $10 billion (USD)', '$500 million to $1 billion (USD)',
#        '$10+ billion (USD)', '$2 to $5 billion (USD)',
#        '$10+ billion (USD)', '$500 million to $1 billion (USD)',
#        '$10+ billion (USD)', '$500 million to $1 billion (USD)',
#        'Unknown / Non-Applicable', '$2 to $5 billion (USD)',
#        '$500 million to $1 billion (USD)', 'Unknown / Non-Applicable',
#        '$1 to $2 billion (USD)', '$1 to $2 billion (USD)',
#        '$500 million to $1 billion (USD)', '$5 to $10 million (USD)',
#        '$50 to $100 million (USD)', '$50 to $100 million (USD)',
#        '$10+ billion (USD)', '$2 to $5 billion (USD)',
#        'Unknown / Non-Applicable', '$10+ billion (USD)',
#        '$100 to $500 million (USD)', 'Unknown / Non-Applicable',
#        '$500 million to $1 billion (USD)', '$100 to $500 million (USD)',
#        'Unknown / Non-Applicable', '$10+ billion (USD)',
#        '$10+ billion (USD)', '$5 to $10 billion (USD)',
#        '$10+ billion (USD)', '$10 to $25 million (USD)',
#        '$100 to $500 million (USD)', '$10+ billion (USD)',
#        '$500 million to $1 billion (USD)', '$100 to $500 million (USD)',
#        '$1 to $2 billion (USD)', '$50 to $100 million (USD)',
#        '$10+ billion (USD)', 'Unknown / Non-Applicable',
#        'Unknown / Non-Applicable', '$10+ billion (USD)',
#        '$10+ billion (USD)', '$1 to $2 billion (USD)',
#        'Unknown / Non-Applicable', '$100 to $500 million (USD)',
#        '$10+ billion (USD)', '$2 to $5 billion (USD)',
#        '$500 million to $1 billion (USD)', '$5 to $10 billion (USD)',
#        '$10+ billion (USD)', '$10+ billion (USD)',
#        '$500 million to $1 billion (USD)', 'Unknown / Non-Applicable',
#        '$25 to $50 million (USD)', '$1 to $2 billion (USD)',
#        '$10+ billion (USD)', 'Unknown / Non-Applicable',
#        '$10+ billion (USD)', '$25 to $50 million (USD)',
#        '$100 to $500 million (USD)', '$500 million to $1 billion (USD)',
#        '$25 to $50 million (USD)', '$100 to $500 million (USD)',
#        '$2 to $5 billion (USD)', '$1 to $2 billion (USD)',
#        '$1 to $2 billion (USD)', 'Unknown / Non-Applicable',
#        '$100 to $500 million (USD)', 'Unknown / Non-Applicable',
#        '$50 to $100 million (USD)', '$500 million to $1 billion (USD)',
#        '$2 to $5 billion (USD)', '$1 to $2 billion (USD)',
#        '$10+ billion (USD)', '$10+ billion (USD)',
#        '$10 to $25 million (USD)', 'Unknown / Non-Applicable',
#        '$10+ billion (USD)', '$50 to $100 million (USD)',
#        'Unknown / Non-Applicable', '$100 to $500 million (USD)',
#        '$100 to $500 million (USD)', '$25 to $50 million (USD)',
#        '$2 to $5 billion (USD)', '$1 to $2 billion (USD)',
#        '$500 million to $1 billion (USD)', '$1 to $2 billion (USD)',
#        '$5 to $10 billion (USD)', 'Unknown / Non-Applicable',
#        '$500 million to $1 billion (USD)', '$100 to $500 million (USD)',
#        '$5 to $10 billion (USD)', 'Unknown / Non-Applicable',
#        '$500 million to $1 billion (USD)', '$50 to $100 million (USD)',
#        '$10+ billion (USD)', '$10+ billion (USD)',
#        '$2 to $5 billion (USD)', '$1 to $2 billion (USD)',
#        '$500 million to $1 billion (USD)', '$10+ billion (USD)',
#        '$500 million to $1 billion (USD)', '$5 to $10 billion (USD)',
#        '$10+ billion (USD)', 'Unknown / Non-Applicable',
#        '$5 to $10 million (USD)', '$2 to $5 billion (USD)',
#        'Unknown / Non-Applicable', '$5 to $10 million (USD)',
#        'Unknown / Non-Applicable', '$25 to $50 million (USD)',
#        '$500 million to $1 billion (USD)', '$10+ billion (USD)',
#        '$25 to $50 million (USD)', '$10+ billion (USD)',
#        '$10+ billion (USD)', '$500 million to $1 billion (USD)',
#        '$10+ billion (USD)', '$10+ billion (USD)',
#        '$10 to $25 million (USD)', 'Unknown / Non-Applicable',
#        '$100 to $500 million (USD)', '$100 to $500 million (USD)',
#        '$500 million to $1 billion (USD)', '$1 to $2 billion (USD)',
#        '$50 to $100 million (USD)', '$10+ billion (USD)',
#        'Unknown / Non-Applicable', '$10+ billion (USD)',
#        '$1 to $2 billion (USD)', '$10 to $25 million (USD)',
#        'Unknown / Non-Applicable', '$100 to $500 million (USD)',
#        '$50 to $100 million (USD)', 'Unknown / Non-Applicable',
#        '$10+ billion (USD)', '$1 to $2 billion (USD)',
#        '$2 to $5 billion (USD)', '$500 million to $1 billion (USD)',
#        '$500 million to $1 billion (USD)', '$5 to $10 billion (USD)',
#        '$10+ billion (USD)', '$10+ billion (USD)', '$10+ billion (USD)',
#        '$500 million to $1 billion (USD)', 'Unknown / Non-Applicable',
#        '$25 to $50 million (USD)', '$1 to $2 billion (USD)',
#        '$10+ billion (USD)', 'Unknown / Non-Applicable',
#        '$10+ billion (USD)', '$100 to $500 million (USD)',
#        '$25 to $50 million (USD)', '$500 million to $1 billion (USD)',
#        '$25 to $50 million (USD)', '$100 to $500 million (USD)',
#        '$2 to $5 billion (USD)', '$1 to $2 billion (USD)',
#        '$1 to $2 billion (USD)', 'Unknown / Non-Applicable',
#        '$100 to $500 million (USD)', 'Unknown / Non-Applicable',
#        '$50 to $100 million (USD)'], dtype=object)

# %%
X2 = df

# %%
X2 = df._get_numeric_data()
X2
# Out:
#      Rating  Founded  Hourly  Employer Provided  Min. Salary  Max. Salary  \
# 0       3.8     1973       0                  0        53000        91000
# 1       3.4     1984       0                  0        63000       112000
# 2       3.8     1965       0                  0        56000        97000
# 3       2.9     1998       0                  0        86000       143000
# 4       3.4     2000       0                  0        71000       119000
# ..      ...      ...     ...                ...          ...          ...
# 364     3.2     1958       0                  0        56000        99000
# 365     3.3     1976       1                  1        50000        56000
# 366     3.4     1988       0                  0        61000       119000
# 367     2.6     1984       0                  0        56000        91000
# 368     3.6     1967       0                  0        61000       126000
#
#      Avg. Salary  Same State  Age  Python Exp.  Spark Exp.  AWS Exp.  \
# 0        72000.0           0   47            1           0         0
# 1        87500.0           0   36            1           0         0
# 2        76500.0           1   55            1           0         0
# 3       114500.0           1   22            1           0         0
# 4        95000.0           1   20            1           0         1
# ..           ...         ...  ...          ...         ...       ...
# 364      77500.0           0   62            0           0         0
# 365      26500.0           1   44            0           0         0
# 366      90000.0           1   32            0           1         0
# 367      73500.0           1   36            0           0         0
# 368      93500.0           0   53            1           0         0
#
#      Excel Exp.  Description Length  # of Competitors
# 0             1                2536                 0
# 1             0                4783                 0
# 2             0                3883                 3
# 3             1                2728                 3
# 4             1                3747                 3
# ..          ...                 ...               ...
# 364           0                3243                 3
# 365           1                1848                 0
# 366           1                2752                 0
# 367           1                3078                 0
# 368           0                3673                 0
#
# [369 rows x 15 columns]

# %%
df.select_dtypes(exclude=['number']).head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $56K-$97K (Glassdoor est.)
# 3             Data Scientist  $86K-$143K (Glassdoor est.)
# 4             Data Scientist  $71K-$119K (Glassdoor est.)
#
#                                      Job Description  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...
# 1  What You Will Do:\n\nI. General Summary\n\nThe...
# 2  *Organization and Job ID**\nJob ID: 310709\n\n...
# 3  Data Scientist\nAffinity Solutions / Marketing...
# 4  CyrusOne is seeking a talented Data Scientist ...
#
#                                  Company Name         Location             HQ  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM     Goleta, CA
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  Baltimore, MD
# 2                                   PNNL\n3.8     Richland, WA   Richland, WA
# 3                     Affinity Solutions\n2.9     New York, NY   New York, NY
# 4                               CyrusOne\n3.4       Dallas, TX     Dallas, TX
#
#                      Size   Type of Ownership  \
# 0   501 to 1000 employees   Company - Private
# 1        10000+ employees  Other Organization
# 2  1001 to 5000 employees          Government
# 3     51 to 200 employees   Company - Private
# 4    201 to 500 employees    Company - Public
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                            Energy  Oil, Gas, Energy & Utilities
# 3           Advertising & Marketing             Business Services
# 4                       Real Estate                   Real Estate
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2  $500 million to $1 billion (USD)
# 3          Unknown / Non-Applicable
# 4            $1 to $2 billion (USD)
#
#                                          Competitors  \
# 0                                                 -1
# 1                                                 -1
# 2  Oak Ridge National Laboratory, National Renewa...
# 3               Commerce Signals, Cardlytics, Yodlee
# 4                  Digital Realty, CoreSite, Equinix
#
#                              company_txt Job State Title Simplified Seniority
# 0                      Tecolote Research        NM   Data Scientist        na
# 1  University of Maryland Medical System        MD   Data Scientist        na
# 2                                   PNNL        WA   Data Scientist        na
# 3                     Affinity Solutions        NY   Data Scientist        na
# 4                               CyrusOne        TX   Data Scientist        na

# %%
df.shape
# Out:
# (369, 31)

# %%
df_char = df.select_dtypes(exclude=['number'])
y = df_char.iloc[:,10]

# %%
df_char.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $56K-$97K (Glassdoor est.)
# 3             Data Scientist  $86K-$143K (Glassdoor est.)
# 4             Data Scientist  $71K-$119K (Glassdoor est.)
#
#                                      Job Description  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...
# 1  What You Will Do:\n\nI. General Summary\n\nThe...
# 2  *Organization and Job ID**\nJob ID: 310709\n\n...
# 3  Data Scientist\nAffinity Solutions / Marketing...
# 4  CyrusOne is seeking a talented Data Scientist ...
#
#                                  Company Name         Location             HQ  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM     Goleta, CA
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  Baltimore, MD
# 2                                   PNNL\n3.8     Richland, WA   Richland, WA
# 3                     Affinity Solutions\n2.9     New York, NY   New York, NY
# 4                               CyrusOne\n3.4       Dallas, TX     Dallas, TX
#
#                      Size   Type of Ownership  \
# 0   501 to 1000 employees   Company - Private
# 1        10000+ employees  Other Organization
# 2  1001 to 5000 employees          Government
# 3     51 to 200 employees   Company - Private
# 4    201 to 500 employees    Company - Public
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                            Energy  Oil, Gas, Energy & Utilities
# 3           Advertising & Marketing             Business Services
# 4                       Real Estate                   Real Estate
#
#                             Revenue  \
# 0         $50 to $100 million (USD)
# 1            $2 to $5 billion (USD)
# 2  $500 million to $1 billion (USD)
# 3          Unknown / Non-Applicable
# 4            $1 to $2 billion (USD)
#
#                                          Competitors  \
# 0                                                 -1
# 1                                                 -1
# 2  Oak Ridge National Laboratory, National Renewa...
# 3               Commerce Signals, Cardlytics, Yodlee
# 4                  Digital Realty, CoreSite, Equinix
#
#                              company_txt Job State Title Simplified Seniority
# 0                      Tecolote Research        NM   Data Scientist        na
# 1  University of Maryland Medical System        MD   Data Scientist        na
# 2                                   PNNL        WA   Data Scientist        na
# 3                     Affinity Solutions        NY   Data Scientist        na
# 4                               CyrusOne        TX   Data Scientist        na

# %%
test_fraction = 0.2
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size=test_fraction)

my_scaler =  StandardScaler()

my_scaler.fit(X_train)
X_train_scaled = my_scaler.transform(X_train)
X_test_scaled = my_scaler.transform(X_test)

# %%
X_test
# Out:
#      Rating  Founded  Hourly  Employer Provided  Min. Salary  Max. Salary  \
# 255     3.9     1913       0                  0       102000       172000
# 140     3.5     1952       0                  0        75000       124000
# 238     3.9     1913       0                  0       107000       173000
# 355     3.2     1975       0                  0        91000       159000
# 213     3.6     1989       0                  0       124000       199000
# ..      ...      ...     ...                ...          ...          ...
# 93      4.0     2002       0                  0        60000       127000
# 18      3.5     1985       0                  0        74000       138000
# 79      3.9     1976       0                  0       131000       207000
# 353     4.4     1984       0                  0       108000       171000
# 298     3.0     1994       0                  0        71000       129000
#
#      Avg. Salary  Same State  Age  Python Exp.  Spark Exp.  AWS Exp.  \
# 255     137000.0           0  107            1           0         0
# 140      99500.0           0   68            1           1         1
# 238     140000.0           0  107            1           0         0
# 355     125000.0           1   45            1           0         1
# 213     161500.0           1   31            1           0         1
# ..           ...         ...  ...          ...         ...       ...
# 93       93500.0           1   18            0           0         0
# 18      106000.0           1   35            1           0         0
# 79      169000.0           1   44            1           1         0
# 353     139500.0           1   36            1           0         0
# 298     100000.0           1   26            0           0         0
#
#      Excel Exp.  Description Length  # of Competitors
# 255           0                3169                 3
# 140           1                4420                 0
# 238           1                4572                 3
# 355           1                3516                 3
# 213           1                5121                 0
# ..          ...                 ...               ...
# 93            1                4637                 0
# 18            1                1739                 0
# 79            1                7106                 0
# 353           0                2518                 0
# 298           1                7777                 3
#
# [74 rows x 15 columns]

# %%
X_test_scaled
# Out:
# array([[ 0.53486295, -2.26692642, -0.24728744, ..., -0.9966159 ,
#         -0.44445546,  1.1373165 ],
#        [-0.21470745, -0.76491142, -0.24728744, ...,  1.0033956 ,
#          0.37541071, -0.94228082],
#        [ 0.53486295, -2.26692642, -0.24728744, ...,  1.0033956 ,
#          0.47502674,  1.1373165 ],
#        ...,
#        [ 0.53486295,  0.1594055 , -0.24728744, ...,  1.0033956 ,
#          2.13573086, -0.94228082],
#        [ 1.47182595,  0.46751115, -0.24728744, ..., -0.9966159 ,
#         -0.87110044, -0.94228082],
#        [-1.15167046,  0.8526432 , -0.24728744, ...,  1.0033956 ,
#          2.57548322,  1.1373165 ]])

# %%
X_train[:]
# Out:
#      Rating  Founded  Hourly  Employer Provided  Min. Salary  Max. Salary  \
# 58      2.8     2000       0                  0        82000       133000
# 144     4.6     1982       0                  0        52000        99000
# 151     3.9     1947       0                  0        38000        82000
# 262     3.2     1975       0                  0        91000       159000
# 154     2.2     1993       0                  0        84000       136000
# ..      ...      ...     ...                ...          ...          ...
# 366     3.4     1988       0                  0        61000       119000
# 345     3.5     1996       0                  0        42000        86000
# 318     3.5     1970       0                  0        68000       129000
# 346     4.0     1982       0                  0       116000       208000
# 4       3.4     2000       0                  0        71000       119000
#
#      Avg. Salary  Same State  Age  Python Exp.  Spark Exp.  AWS Exp.  \
# 58      107500.0           1   20            1           0         0
# 144      75500.0           0   38            0           1         0
# 151      60000.0           1   73            0           0         0
# 262     125000.0           1   45            1           0         1
# 154     110000.0           0   27            0           0         0
# ..           ...         ...  ...          ...         ...       ...
# 366      90000.0           1   32            0           1         0
# 345      64000.0           1   24            0           0         0
# 318      98500.0           0   50            1           1         1
# 346     162000.0           1   38            1           0         0
# 4        95000.0           1   20            1           0         1
#
#      Excel Exp.  Description Length  # of Competitors
# 58            0                3899                 0
# 144           0                2047                 0
# 151           0                2026                 3
# 262           1                3516                 3
# 154           0                6612                 3
# ..          ...                 ...               ...
# 366           1                2752                 0
# 345           0                3846                 0
# 318           0                3926                 2
# 346           1                3864                 2
# 4             1                3747                 3
#
# [295 rows x 15 columns]

# %%
X_train[:,]
# Out:
#      Rating  Founded  Hourly  Employer Provided  Min. Salary  Max. Salary  \
# 58      2.8     2000       0                  0        82000       133000
# 144     4.6     1982       0                  0        52000        99000
# 151     3.9     1947       0                  0        38000        82000
# 262     3.2     1975       0                  0        91000       159000
# 154     2.2     1993       0                  0        84000       136000
# ..      ...      ...     ...                ...          ...          ...
# 366     3.4     1988       0                  0        61000       119000
# 345     3.5     1996       0                  0        42000        86000
# 318     3.5     1970       0                  0        68000       129000
# 346     4.0     1982       0                  0       116000       208000
# 4       3.4     2000       0                  0        71000       119000
#
#      Avg. Salary  Same State  Age  Python Exp.  Spark Exp.  AWS Exp.  \
# 58      107500.0           1   20            1           0         0
# 144      75500.0           0   38            0           1         0
# 151      60000.0           1   73            0           0         0
# 262     125000.0           1   45            1           0         1
# 154     110000.0           0   27            0           0         0
# ..           ...         ...  ...          ...         ...       ...
# 366      90000.0           1   32            0           1         0
# 345      64000.0           1   24            0           0         0
# 318      98500.0           0   50            1           1         1
# 346     162000.0           1   38            1           0         0
# 4        95000.0           1   20            1           0         1
#
#      Excel Exp.  Description Length  # of Competitors
# 58            0                3899                 0
# 144           0                2047                 0
# 151           0                2026                 3
# 262           1                3516                 3
# 154           0                6612                 3
# ..          ...                 ...               ...
# 366           1                2752                 0
# 345           0                3846                 0
# 318           0                3926                 2
# 346           1                3864                 2
# 4             1                3747                 3
#
# [295 rows x 15 columns]

# %%
plt.scatter(X_train[:,0], X_train[:,1], label='original')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /Users/sharodwilliams/Git/CMSE830/Untitled-1.ipynb Cell 28 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/sharodwilliams/Git/CMSE830/Untitled-1.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> plt.scatter(X_train[:,0], X_train[:,1], label='original')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3636, in Index.get_loc(self, key, method, tolerance)
#    3631         raise KeyError(key) from err
#    3632     except TypeError:
#    3633         # If we have a listlike key, _check_indexing_error will raise
#    3634         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635         #  the TypeError.
# -> 3636         self._check_indexing_error(key)
#    3637         raise
#    3639 # GH#42269
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5651, in Index._check_indexing_error(self, key)
#    5647 def _check_indexing_error(self, key):
#    5648     if not is_scalar(key):
#    5649         # if key is not a scalar, directly raise an error (the code below
#    5650         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5651         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), 0)

# %%
px.scatter(df_orig, x=X_train[:,0], y= X_train[:,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sharodwilliams/Git/CMSE830/Untitled-1.ipynb Cell 28 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/sharodwilliams/Git/CMSE830/Untitled-1.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> px.scatter(df_orig, x=X_train[:,0], y= X_train[:,1])
#
# NameError: name 'df_orig' is not defined
